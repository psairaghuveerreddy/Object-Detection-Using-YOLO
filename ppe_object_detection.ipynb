# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.8 MB/s eta 0:00:00
# ...

# %%
# !unzip /content/construction site safety.v3i.yolov8.zip
# Out:
# unzip:  cannot find or open /content/construction, /content/construction.zip or /content/construction.ZIP.

# %%
# !ls
# Out:
# 'construction site safety.v3i.yolov8.zip'   sample_data

# %%
# !unzip "construction site safety.v3i.yolov8.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/labels/airport_inside_0363_jpg.rf.e717c655da4f82f6699ad74c9e628042.txt
#   inflating: train/labels/airport_inside_0363_jpg.rf.ebff5105924d396c5a9bcc81f14249ff.txt
#   inflating: train/labels/airport_inside_0449_jpg.rf.4d4e59df8489a52456990bea434fd62b.txt
#   inflating: train/labels/airport_inside_0449_jpg.rf.6589301d12f45c5e26f65ebb777ed45a.txt
#   inflating: train/labels/airport_inside_0449_jpg.rf.7ade08d48d1c0bb4608764a8f144e500.txt
#   inflating: train/labels/airport_inside_0449_jpg.rf.7cee031436e0baecd5a8177e68f8aa59.txt
#   inflating: train/labels/airport_inside_0449_jpg.rf.80a204632d71b912b98d88aa8dea250a.txt
#   inflating: train/labels/airport_inside_0449_jpg.rf.e2538ad9453ab41e50ad300352eef72e.txt
#   inflating: train/labels/airport_inside_0449_jpg.rf.e4b0e6268048916c692f5ee6af393fcb.txt
#   inflating: train/labels/airport_inside_0449_jpg.rf.f484c94085a65d42c24c372dd2ebcaa1.txt
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="data.yaml",
    epochs=30,
    imgsz=640,
    batch=16
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.47 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
